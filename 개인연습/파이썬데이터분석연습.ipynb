# %% [markdown]
# ## chapter 2

# %%
# 세트는 인덱스가 없음

# %%
new_score = [s+5 if s<100 else s for s in scores]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d40aced69bb1> in <module>
# ----> 1 new_score = [s+5 if s<100 else s for s in scores]
#
# NameError: name 'scores' is not defined

# %%
weight = lambda height:(height-100)*0.9

# %%
code = '가나다'
if code.isdigit()==False:
    print("숫자를 입력하세요")

# %% [markdown]
# ## chapter 3

# %%
import pandas as pd

# %%
df.describe()
df.info()
df['칼럼명'].unique() # 데이터 종류 중복 제거 후 보여줌
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-efd01547bc79> in <module>
# ----> 1 df.describe()
#       2 df.info()
#       3 df['칼럼명'].unique() # 데이터 종류 중복 제거 후 보여줌
#
# NameError: name 'df' is not defined

# %%
df1 = pd.DataFrame({'이름':['A','B','D'],
                   '성별':['남자','여자','남자']
                   })
df1
# Out:
#   이름  성별
# 0  A  남자
# 1  B  여자
# 2  D  남자

# %%
df2 = pd.DataFrame({'이름':['A','B','C'],
                   '키':[180,160,150]
                   })
df2
# Out:
#   이름    키
# 0  A  180
# 1  B  160
# 2  C  150

# %%
pd.merge(df1,df2)
# Out:
#   이름  성별    키
# 0  A  남자  180
# 1  B  여자  160

# %%
pd.merge(df1,df2,how='right')
# Out:
#   이름   성별    키
# 0  A   남자  180
# 1  B   여자  160
# 2  C  NaN  150

# %%
pd.merge(df1,df2,how='outer')
# Out:
#   이름   성별      키
# 0  A   남자  180.0
# 1  B   여자  160.0
# 2  D   남자    NaN
# 3  C  NaN  150.0

# %%
pd.concat([df1,df2])
# Out:
#   이름   성별      키
# 0  A   남자    NaN
# 1  B   여자    NaN
# 2  D   남자    NaN
# 0  A  NaN  180.0
# 1  B  NaN  160.0
# 2  C  NaN  150.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#   이름  성별 이름    키
# 0  A  남자  A  180
# 1  B  여자  B  160
# 2  D  남자  C  150

# %% [markdown]
# #### 문제

# %%
conda install pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dbqhgus13\anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa95532_0         2.9 MB
#     pandas-datareader-0.10.0   |     pyhd3eb1b0_0          71 KB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-datareader  pkgs/main/noarch::pandas-datareader-0.10.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.3-py38_0 --> 4.10.3-py38haa95532_0
#
#
#
# ...
#
# conda-4.10.3         | 2.9 MB    |            |   0%
# conda-4.10.3         | 2.9 MB    |            |   1%
# ...

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data

# %%
df = data.get_data_yahoo('005930.KS',"2020-01-01")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 448 entries, 2020-01-02 to 2021-10-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       448 non-null    float64
#  1   Low        448 non-null    float64
#  2   Open       448 non-null    float64
#  3   Close      448 non-null    float64
#  4   Volume     448 non-null    float64
#  5   Adj Close  448 non-null    float64
# dtypes: float64(6)
# memory usage: 24.5 KB

# %%
df.describe() #1
# Out:
#                High           Low          Open         Close        Volume  \
# count    448.000000    448.000000    448.000000    448.000000  4.480000e+02
# mean   68211.830357  66876.897321  67542.410714  67502.008929  2.083956e+07
# std    13054.327824  12976.383935  12994.932259  12985.225057  9.643185e+06
# min    43550.000000  42300.000000  42600.000000  42500.000000  0.000000e+00
# 25%    56875.000000  55500.000000  56175.000000  56050.000000  1.447220e+07
# 50%    68300.000000  66600.000000  67500.000000  67600.000000  1.837876e+07
# 75%    81300.000000  80100.000000  80800.000000  80625.000000  2.430475e+07
# max    96800.000000  89500.000000  90300.000000  91000.000000  9.030618e+07
#
#           Adj Close
# count    448.000000
# mean   66038.284589
# std    13869.492262
# min    40271.523438
# 25%    53513.749023
# 50%    65359.400391
# 75%    80286.203125
# max    90198.078125

# %%
df['Close'].mean()
# Out:
# 67502.00892857143

# %%
df.shape # 갯수 세기 5번
# Out:
# (448, 6)

# %%
df['Close']
# Out:
# Date
# 2020-01-02    55200.0
# 2020-01-03    55500.0
# 2020-01-06    55500.0
# 2020-01-07    55800.0
# 2020-01-08    56800.0
#                ...
# 2021-10-19    70600.0
# 2021-10-20    70300.0
# 2021-10-21    70200.0
# 2021-10-22    70400.0
# 2021-10-25    70200.0
# Name: Close, Length: 448, dtype: float64

# %%
df.head(3)
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000

# %%
df[df['Open']<df['Close']]
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.148438
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.710938
# 2020-01-09  58600.0  57400.0  58400.0  58600.0  24102579.0  55527.324219
# 2020-01-10  59700.0  58300.0  58800.0  59500.0  16000170.0  56380.136719
# ...             ...      ...      ...      ...         ...           ...
# 2021-09-27  77700.0  77000.0  77300.0  77700.0  11699798.0  77700.000000
# 2021-10-13  69600.0  68300.0  68700.0  68800.0  24172015.0  68800.000000
# 2021-10-14  69800.0  68800.0  69000.0  69400.0  19520641.0  69400.000000
# 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
#
# [191 rows x 6 columns]

# %%
df[df['Close']==df['Close'].max()] # 9번
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-01-11  96800.0  89500.0  90000.0  91000.0  90306177.0  90198.078125

# %%
df[df['Close']>=90000]
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-01-11  96800.0  89500.0  90000.0  91000.0  90306177.0  90198.078125
# 2021-01-12  91400.0  87800.0  90300.0  90600.0  48682416.0  89801.601562

# %%
df[df.index=='2021-01-15']
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-01-15  91800.0  88000.0  89800.0  88000.0  33431809.0  87224.515625

# %%
df.iloc[100]
# Out:
# High         5.070000e+04
# Low          4.970000e+04
# Open         5.000000e+04
# Close        5.070000e+04
# Volume       2.759696e+07
# Adj Close    4.839627e+04
# Name: 2020-05-29 00:00:00, dtype: float64

# %%
df.sort_index(ascending=False) #14번
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
# 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 2021-10-21  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000
# 2021-10-20  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000
# 2021-10-19  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000
# ...             ...      ...      ...      ...         ...           ...
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.710938
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.148438
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
#
# [448 rows x 6 columns]

# %%
df['Close'].sort_values(ascending=False)
# Out:
# Date
# 2021-01-11    91000.0
# 2021-01-12    90600.0
# 2021-01-13    89700.0
# 2021-01-14    89700.0
# 2021-01-25    89400.0
#                ...
# 2020-04-01    45800.0
# 2020-03-18    45600.0
# 2020-03-20    45400.0
# 2020-03-19    42950.0
# 2020-03-23    42500.0
# Name: Close, Length: 448, dtype: float64

# %%
df = df.drop('Date',axis=1)

# %%
df.reset_index(inplace=True)
df   # 인덱스 빼는법 16번
# Out:
#           Date     High      Low     Open    Close      Volume     Adj Close
# 0   2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
# 1   2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2   2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 3   2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.148438
# 4   2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.710938
# ..         ...      ...      ...      ...      ...         ...           ...
# 443 2021-10-19  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000
# 444 2021-10-20  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000
# 445 2021-10-21  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000
# 446 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 447 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
#
# [448 rows x 7 columns]

# %%
df = df.rename(columns={'Date':'날짜','High':'고가','Low':'저가'})

# %%
df = df.drop('날짜',axis=1)

# %%
df['diff'] = df['Close'] - df['Open']
df
# Out:
#           고가       저가     Open    Close      Volume     Adj Close   diff
# 0    56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469 -300.0
# 1    56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000 -500.0
# 2    55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000  600.0
# 3    56400.0  55600.0  55700.0  55800.0  10009778.0  52874.148438  100.0
# 4    57400.0  55900.0  56200.0  56800.0  23501171.0  53821.710938  600.0
# ..       ...      ...      ...      ...         ...           ...    ...
# 443  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000 -200.0
# 444  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000 -400.0
# 445  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000 -100.0
# 446  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000  400.0
# 447  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000  300.0
#
# [448 rows x 7 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#           Date     High      Low     Open    Close      Volume     Adj Close
# 0   2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
# 1   2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2   2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 3   2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.144531
# 4   2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.707031
# ..         ...      ...      ...      ...      ...         ...           ...
# 443 2021-10-19  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000
# 444 2021-10-20  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000
# 445 2021-10-21  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000
# 446 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 447 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
#
# [448 rows x 7 columns]

# %%
df['Year'] = [d.year for d in df['Date']]
df['Month'] = [d.month for d in df['Date']]
df['Day'] = [d.day for d in df['Date']]  # 20

# %%
df['거래량'] = df['Volume'].apply(lambda x : "{:,}".format(x))

# %%
df
# Out:
#           Date     High      Low     Open    Close      Volume     Adj Close  \
# 0   2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
# 1   2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2   2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 3   2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.144531
# 4   2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.707031
# ..         ...      ...      ...      ...      ...         ...           ...
# 443 2021-10-19  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000
# 444 2021-10-20  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000
# 445 2021-10-21  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000
# 446 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 447 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
#
#      Year  Month  Day           거래량
# ...

# %%
volume_mean = df['Volume'].groupby(df['Month']).mean()
volume_mean
# Out:
# Month
# 1     2.713407e+07
# 2     2.086738e+07
# 3     2.649870e+07
# 4     1.897715e+07
# 5     1.911778e+07
# 6     1.933043e+07
# 7     1.584891e+07
# 8     2.198928e+07
# 9     1.768839e+07
# 10    1.673753e+07
# 11    2.363959e+07
# 12    2.523804e+07
# Name: Volume, dtype: float64

# %%
df.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# Year         0
# Month        0
# Day          0
# 거래량          0
# dtype: int64

# %%
df.dropna()
# Out:
#           Date     High      Low     Open    Close      Volume     Adj Close  \
# 0   2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52305.605469
# 1   2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52589.875000
# 2   2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52589.875000
# 3   2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  52874.144531
# 4   2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  53821.707031
# ..         ...      ...      ...      ...      ...         ...           ...
# 443 2021-10-19  71000.0  70400.0  70800.0  70600.0   9507991.0  70600.000000
# 444 2021-10-20  71000.0  70200.0  70700.0  70300.0  10151638.0  70300.000000
# 445 2021-10-21  70600.0  70000.0  70300.0  70200.0  10891094.0  70200.000000
# 446 2021-10-22  70700.0  70000.0  70000.0  70400.0   8395448.0  70400.000000
# 447 2021-10-25  70600.0  69500.0  69900.0  70200.0   9839063.0  70200.000000
#
#      Year  Month  Day           거래량
# ...

# %%
dec_df = df[df['Month']==12]
nov_df = df[df['Month']==11]

# %%
pd.concat([nov_df,dec_df])
# Out:
#           Date     High      Low     Open    Close      Volume     Adj Close  \
# 206 2020-11-02  57500.0  56000.0  56400.0  57400.0  20489076.0  55497.480469
# 207 2020-11-03  58900.0  57600.0  57900.0  58800.0  14950919.0  56851.074219
# 208 2020-11-04  59000.0  57800.0  58900.0  58500.0  21718561.0  56561.019531
# 209 2020-11-05  60300.0  58800.0  59000.0  60300.0  20639475.0  58301.355469
# 210 2020-11-06  60800.0  59600.0  60700.0  60100.0  16910230.0  58107.988281
# 211 2020-11-09  60900.0  60100.0  60700.0  60200.0  15892961.0  58204.671875
# 212 2020-11-10  60500.0  59500.0  60500.0  60200.0  19073552.0  58204.671875
# 213 2020-11-11  61400.0  60400.0  60700.0  61300.0  25628510.0  59268.214844
# 214 2020-11-12  61400.0  60700.0  61000.0  61000.0  19800573.0  58978.156250
# 215 2020-11-13  63200.0  61000.0  61300.0  63200.0  31508829.0  61105.238281
# 216 2020-11-16  66700.0  63900.0  64000.0  66300.0  36354334.0  64102.480469
# ...

# %% [markdown]
# ## chapter 4

# %%
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names() #데이터 불러오기
# Out:
# C:\Users\dbqhgus13\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\dbqhgus13\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['sex'].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],hue=df['sex'])

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],hue=df['sex'],size=df['size'])

# %%
sns.regplot(x=df['total_bill'],y=df['tip'])

# %%
sns.regplot(x=df['total_bill'],y=df['tip'],scatter=False)

# %%
sns.regplot(x=df['total_bill'],y=df['tip'],scatter=False,ci=None)
