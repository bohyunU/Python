# %%
conda install pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa95532_0         2.9 MB
#     pandas-datareader-0.10.0   |     pyhd3eb1b0_0          71 KB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-datareader  pkgs/main/noarch::pandas-datareader-0.10.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   conda                               4.10.1-py38haa95532_1 --> 4.10.3-py38haa95532_0
#
#
#
# ...
#
# pandas-datareader-0. | 71 KB     |            |   0%
# pandas-datareader-0. | 71 KB     | ########9  |  90%
# ...

# %%
# https://finance.yahoo.com/
import pandas as pd
import numpy as np
from pandas_datareader import data

# %%
#samsung electronics
df = data.get_data_yahoo('005930.KS',"2020-01-01")

# %%
df.info()   #2020년 1월부터 2021년 7월
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 388 entries, 2020-01-02 to 2021-07-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       388 non-null    float64
#  1   Low        388 non-null    float64
#  2   Open       388 non-null    float64
#  3   Close      388 non-null    float64
#  4   Volume     388 non-null    float64
#  5   Adj Close  388 non-null    float64
# dtypes: float64(6)
# memory usage: 21.2 KB

# %%
df.describe()
# Out:
#                High           Low          Open         Close        Volume  \
# count    388.000000    388.000000    388.000000    388.000000  3.880000e+02
# mean   66999.226804  65643.170103  66302.061856  66290.206186  2.126576e+07
# std    13561.933708  13462.337108  13476.552357  13484.758147  9.723028e+06
# min    43550.000000  42300.000000  42600.000000  42500.000000  0.000000e+00
# 25%    55900.000000  54600.000000  55200.000000  55275.000000  1.495051e+07
# 50%    60900.000000  59850.000000  60600.000000  60400.000000  1.867483e+07
# 75%    81600.000000  80700.000000  81100.000000  81000.000000  2.500283e+07
# max    96800.000000  89500.000000  90300.000000  91000.000000  9.030618e+07
#
#           Adj Close
# count    388.000000
# mean   64868.813386
# std    14354.976575
# min    40449.824219
# 25%    52816.114258
# 50%    58354.087891
# 75%    81000.000000
# max    90597.414062

# %%
df['Close'].max()
# Out:
# 91000.0

# %%
df['Close'].min()
# Out:
# 42500.0

# %%
df['Close'].mean()
# Out:
# 66290.206185567

# %%
df.shape
# Out:
# (388, 6)

# %%
df[['Close','High']]
# Out:
#               Close     High
# Date
# 2020-01-02  55200.0  56000.0
# 2020-01-03  55500.0  56600.0
# 2020-01-06  55500.0  55600.0
# 2020-01-07  55800.0  56400.0
# 2020-01-08  56800.0  57400.0
# ...             ...      ...
# 2021-07-19  79000.0  79200.0
# 2021-07-20  79000.0  79000.0
# 2021-07-21  78500.0  79100.0
# 2021-07-22  79700.0  79800.0
# 2021-07-23  79300.0  79900.0
#
# [388 rows x 2 columns]

# %%
df.head(3)
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031

# %%
df[df['Open']<df['Close']]
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# 2020-01-09  58600.0  57400.0  58400.0  58600.0  24102579.0  55773.164062
# 2020-01-10  59700.0  58300.0  58800.0  59500.0  16000170.0  56629.746094
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-06  81200.0  80500.0  80600.0  81200.0  12131651.0  81200.000000
# 2021-07-14  79600.0  79100.0  79400.0  79500.0  11575636.0  79500.000000
# 2021-07-15  80600.0  79500.0  79800.0  80600.0  13766279.0  80600.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
#
# [172 rows x 6 columns]

# %%
df[df['Close']==df['Close'].max()]
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-01-11  96800.0  89500.0  90000.0  91000.0  90306177.0  90597.414062

# %%
df[df['Close']>=90000].index
# Out:
# DatetimeIndex(['2021-01-11', '2021-01-12'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df[df.index=="2021-01-15"]
# Out:
#                High      Low     Open    Close      Volume   Adj Close
# Date
# 2021-01-15  91800.0  88000.0  89800.0  88000.0  33431809.0  87610.6875

# %%
df[df.index=="2021-01-11"][['High','Low']]
# Out:
#                High      Low
# Date
# 2021-01-11  96800.0  89500.0

# %%
df.iloc[100]
# Out:
# High         5.070000e+04
# Low          4.970000e+04
# Open         5.000000e+04
# Close        5.070000e+04
# Volume       2.759696e+07
# Adj Close    4.861053e+04
# Name: 2020-05-29 00:00:00, dtype: float64

# %%
df.sort_index(ascending=False)
# Out:
#                High      Low     Open    Close      Volume     Adj Close
# Date
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# ...             ...      ...      ...      ...         ...           ...
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
#
# [388 rows x 6 columns]

# %%
df['Close'].sort_values(ascending=False)
# Out:
# Date
# 2021-01-11    91000.0
# 2021-01-12    90600.0
# 2021-01-13    89700.0
# 2021-01-14    89700.0
# 2021-01-25    89400.0
#                ...
# 2020-04-01    45800.0
# 2020-03-18    45600.0
# 2020-03-20    45400.0
# 2020-03-19    42950.0
# 2020-03-23    42500.0
# Name: Close, Length: 388, dtype: float64

# %%
df['Date']=df.index

# %%
df=df.rename(columns={'Date':'날짜','High':'고가','Low':'저가'})

# %%
df.drop('날짜',axis=1)
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
#
# [388 rows x 6 columns]

# %%
df['diff']=df['Close']-df['Open']

# %%
df
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close  \
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
#
#                    날짜   diff
# Date
# 2020-01-02 2020-01-02 -300.0
# ...

# %%
df['year']=[d.year for d in df['날짜']]

# %%
df['month']=[d.month for d in df['날짜']]
df['day']=[d.day for d in df['날짜']]

# %%
df
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close  \
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
#
#                    날짜   diff  year  month  day
# Date
# ...

# %%
df['거래량'] = df['Volume'].apply(lambda x : "{:,}".format(x))

# %%
df
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close  \
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
#
#                    날짜   diff  year  month  day           거래량
# Date
# ...

# %%
volume_mean = df['Volume'].groupby(df['month']).mean()
volume_mean
# Out:
# month
# 1     2.713407e+07
# 2     2.086738e+07
# 3     2.649870e+07
# 4     1.897715e+07
# 5     1.911778e+07
# 6     1.933043e+07
# 7     1.627012e+07
# 8     2.008490e+07
# 9     2.030011e+07
# 10    1.723988e+07
# 11    2.363959e+07
# 12    2.523804e+07
# Name: Volume, dtype: float64

# %%
df.isnull().sum()
# Out:
# 고가           0
# 저가           0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# 날짜           0
# diff         0
# year         0
# month        0
# day          0
# 거래량          0
# dtype: int64

# %%
df.dropna()
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close  \
# Date
# 2020-01-02  56000.0  55000.0  55500.0  55200.0  12993228.0  52537.179688
# 2020-01-03  56600.0  54900.0  56000.0  55500.0  15422255.0  52822.707031
# 2020-01-06  55600.0  54600.0  54900.0  55500.0  10278951.0  52822.707031
# 2020-01-07  56400.0  55600.0  55700.0  55800.0  10009778.0  53108.238281
# 2020-01-08  57400.0  55900.0  56200.0  56800.0  23501171.0  54059.992188
# ...             ...      ...      ...      ...         ...           ...
# 2021-07-19  79200.0  78800.0  79100.0  79000.0  13155414.0  79000.000000
# 2021-07-20  79000.0  78400.0  78500.0  79000.0  12456646.0  79000.000000
# 2021-07-21  79100.0  78500.0  79000.0  78500.0  12355296.0  78500.000000
# 2021-07-22  79800.0  78900.0  79000.0  79700.0  12618790.0  79700.000000
# 2021-07-23  79900.0  79200.0  79700.0  79300.0   9098910.0  79300.000000
#
#                    날짜   diff  year  month  day           거래량
# Date
# ...

# %%
dec_df = df[df['month']==12]
nov_df = df[df['month']==11]

# %%
plus_df = pd.concat([nov_df,dec_df])

# %%
plus_df
# Out:
#                  고가       저가     Open    Close      Volume     Adj Close  \
# Date
# 2020-11-02  57500.0  56000.0  56400.0  57400.0  20489076.0  55743.183594
# 2020-11-03  58900.0  57600.0  57900.0  58800.0  14950919.0  57102.777344
# 2020-11-04  59000.0  57800.0  58900.0  58500.0  21718561.0  56811.433594
# 2020-11-05  60300.0  58800.0  59000.0  60300.0  20639475.0  58559.480469
# 2020-11-06  60800.0  59600.0  60700.0  60100.0  16910230.0  58365.253906
# 2020-11-09  60900.0  60100.0  60700.0  60200.0  15892961.0  58462.363281
# 2020-11-10  60500.0  59500.0  60500.0  60200.0  19073552.0  58462.363281
# 2020-11-11  61400.0  60400.0  60700.0  61300.0  25628510.0  59530.613281
# 2020-11-12  61400.0  60700.0  61000.0  61000.0  19800573.0  59239.273438
# 2020-11-13  63200.0  61000.0  61300.0  63200.0  31508829.0  61375.773438
# 2020-11-16  66700.0  63900.0  64000.0  66300.0  36354334.0  64386.292969
# 2020-11-17  67000.0  65600.0  67000.0  65700.0  30204089.0  63803.609375
# ...
